# %% [markdown]
# # Экспоненциальное распределение Хи2 для простой гипотезы

# %%
import random
import math
from math import e
import numpy as np
import pandas as pd

# %%
def make_expon_viborka(n, lam = 0.8):
    lst = []
    for i in range(n):
        r = random.random()
        x = -math.log(r,math.e) / lam
        lst.append(float('{:.3f}'.format(x)))
    
    return lst

# %%
#n = int(input()) # объем выборки
n = 100

# %%
my_list = make_expon_viborka(n)

# %%
my_set = list(set(my_list))
amount = []

for i in my_set:
    a = my_list.count(i)
    amount.append(a)


new_list = sorted(my_list)

number = 5 # количество чисел в интервале
count = 1 # cчетчик сколько чисел в интервале

final_interval = []
final_interval.append(new_list[0])

for i in new_list:
    if count == number:
        final_interval.append(i + 0.01)
        count = 0
    count += 1
#print(count)

print(final_interval)

final_interval_2 = final_interval[1:]
final_interval.pop(-1)
#final_interval_2.append(new_list[-1])

#print(new_list)
print(final_interval)
print(final_interval_2)



n_list = [number] * len(final_interval)
if len(n_list) != len(final_interval):
    n_list.append(count)


#print(list(map(len, [final_interval, final_interval_2, n_list])))
#print(new_list)
# Out:
# [0.006, 0.047, 0.157, 0.219, 0.302, 0.406, 0.497, 0.668, 0.704, 0.85, 0.993, 1.203, 1.386, 1.563, 1.661, 1.981, 2.146, 2.4419999999999997, 2.617, 3.355, 5.274]
# [0.006, 0.047, 0.157, 0.219, 0.302, 0.406, 0.497, 0.668, 0.704, 0.85, 0.993, 1.203, 1.386, 1.563, 1.661, 1.981, 2.146, 2.4419999999999997, 2.617, 3.355]
# [0.047, 0.157, 0.219, 0.302, 0.406, 0.497, 0.668, 0.704, 0.85, 0.993, 1.203, 1.386, 1.563, 1.661, 1.981, 2.146, 2.4419999999999997, 2.617, 3.355, 5.274]

# %%
def table(): 
    
    p = 0.8 # оценка парметра p
    
    print('Параметер равен: ', p)
    

    data = {'x_k': final_interval,
           'x_k+1': final_interval_2,
            'n_k': n_list}


    df = pd.DataFrame(data)
    
    df['P_k'] = np.around(e**(-p * df['x_k']) - e**(-p * df['x_k+1']), 3)
    df['n_k_2'] = np.around(n * df['P_k'], 3)
    df['Мера'] = np.around((df['n_k'] - df['n_k_2'])**2 / (df['n_k_2']), 3)
    df.loc['Сумма']= df.sum()
    display(df)

# %%
table()
# Out:
# Параметер равен:  0.8
#           x_k   x_k+1    n_k    P_k  n_k_2    Мера
# 0       0.006   0.047    5.0  0.032    3.2   1.012
# 1       0.047   0.157    5.0  0.081    8.1   1.186
# 2       0.157   0.219    5.0  0.043    4.3   0.114
# 3       0.219   0.302    5.0  0.054    5.4   0.030
# 4       0.302   0.406    5.0  0.063    6.3   0.268
# 5       0.406   0.497    5.0  0.051    5.1   0.002
# 6       0.497   0.668    5.0  0.086    8.6   1.507
# 7       0.668   0.704    5.0  0.017    1.7   6.406
# 8       0.704   0.850    5.0  0.063    6.3   0.268
# 9       0.850   0.993    5.0  0.055    5.5   0.045
# 10      0.993   1.203    5.0  0.070    7.0   0.571
# 11      1.203   1.386    5.0  0.052    5.2   0.008
# 12      1.386   1.563    5.0  0.044    4.4   0.082
# 13      1.563   1.661    5.0  0.022    2.2   3.564
# 14      1.661   1.981    5.0  0.060    6.0   0.167
# 15      1.981   2.146    5.0  0.025    2.5   2.500
# 16      2.146   2.442    5.0  0.038    3.8   0.379
# 17      2.442   2.617    5.0  0.019    1.9   5.058
# 18      2.617   3.355    5.0  0.055    5.5   0.045
# 19      3.355   5.274    5.0  0.054    5.4   0.030
# Сумма  23.203  28.471  100.0  0.984   98.4  23.242
