# %% [markdown]
# # Геометрическое распределение для простой гипотезы

# %%
import random
import numpy as np
import pylab
import math 
import scipy.stats as st
import pandas as pd

# %%
# Моделирование выборки, подчняющуюся геометрическому распределению
def make_geom_viborka(n, p = 0.2, m = 5):
    lst = []
    for i in range(n):
        a = random.random()
        e = math.floor(math.log(a,math.e) / math.log(1 - p,math.e) )
        lst.append(e)     
    return lst

# %%
#n = int(input()) # объем выборки
n = 10000

# %%
my_list = make_geom_viborka(n)

# %%
my_set = list(set(my_list))
amount = []

for i in my_set:
    a = my_list.count(i)
    amount.append(a)

# %% [markdown]
# # Сдеалаем свобдную таблицу

# %%
def table(): 
    
    p = 0.2 # оценка парметра p
    
    print('Параметр равен: ', p)
    list_p_i = [] # теоретические вероятности 

    for elem in my_set:
        p_i = p * (1 - p)**elem
        list_p_i.append(np.around(p_i, 3))

    list_n = [] # теоретические частоты

    for elem in list_p_i:
        list_n.append(n * elem)


    #print(list(map(len, [my_set, amount, list_p_i, list_n])))
    # Делаем таблицу:

    my_set.append(sum(my_set))
    amount.append(sum(amount))
    list_p_i.append(sum(list_p_i))
    list_n.append(sum(list_n))

    #print(list(map(len, [my_set, amount, list_p_i, list_n])))

    data = {'k': my_set,
           'n_k': amount,
           'p_k': list_p_i,
           'n_k_2': list_n}

    m = list(range(len(my_set) - 1))
    m.append('Сумма')

    #print(m)
    #print(len(m))
    df = pd.DataFrame(data, index = m)
    
    df['Мера'] = np.around((df['n_k'] - df['n_k_2'])**2 / (df['n_k_2']), 3)
    display(df)

# %%
table()
# Out:
# Параметр равен:  0.2
#          k    n_k    p_k   n_k_2   Мера
# 0        0   1969  0.200  2000.0  0.480
# 1        1   1681  0.160  1600.0  4.101
# 2        2   1307  0.128  1280.0  0.570
# 3        3   1001  0.102  1020.0  0.354
# 4        4    867  0.082   820.0  2.694
# 5        5    652  0.066   660.0  0.097
# 6        6    527  0.052   520.0  0.094
# 7        7    404  0.042   420.0  0.610
# 8        8    321  0.034   340.0  1.062
# 9        9    284  0.027   270.0  0.726
# 10      10    184  0.021   210.0  3.219
# 11      11    156  0.017   170.0  1.153
# 12      12    143  0.014   140.0  0.064
# 13      13     96  0.011   110.0  1.782
# 14      14     87  0.009    90.0  0.100
# 15      15     67  0.007    70.0  0.129
# 16      16     49  0.006    60.0  2.017
# 17      17     33  0.005    50.0  5.780
# 18      18     31  0.004    40.0  2.025
# 19      19     27  0.003    30.0  0.300
# 20      20     23  0.002    20.0  0.450
# 21      21     13  0.002    20.0  2.450
# 22      22     17  0.001    10.0  4.900
# 23      23     11  0.001    10.0  0.100
# 24      24      8  0.001    10.0  0.400
# 25      25      7  0.001    10.0  0.900
# 26      26      5  0.001    10.0  2.500
# 27      27      7  0.000     0.0    inf
# 28      28      7  0.000     0.0    inf
# 29      29      4  0.000     0.0    inf
# 30      30      1  0.000     0.0    inf
# 31      31      4  0.000     0.0    inf
# 32      34      1  0.000     0.0    inf
# 33      35      1  0.000     0.0    inf
# 34      36      1  0.000     0.0    inf
# 35      37      1  0.000     0.0    inf
# 36      39      1  0.000     0.0    inf
# 37      43      1  0.000     0.0    inf
# 38      53      1  0.000     0.0    inf
# Сумма  773  10000  0.999  9990.0  0.010
